# %% [markdown]
# ChatMessageHistory是一个用于 存储和管理对话消息 的基础类，
# 它直接操作消息对象（如HumanMessage, AIMessage 等），是其它记忆组件的底层存储工具。
# 在API文档中，ChatMessageHistory 还有一个别名类：InMemoryChatMessageHistory；
# 导包时，需使用：from langchain.memory import ChatMessageHistory
# 特点：
# 纯粹是消息对象的“ 存储器 ”，与记忆策略（如缓冲、窗口、摘要等）无关。
# 不涉及消息的格式化（如转成文本字符串）

# %% [markdown]
# 场景1：记忆存储

# %%
from langchain.memory import ChatMessageHistory

history=ChatMessageHistory()
history.add_user_message("hi")
history.add_ai_message("what's up?")
print(history.messages)
# Out:
# [HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content="what's up?", additional_kwargs={}, response_metadata={})]

# %% [markdown]
# 场景2：对接LLM

# %%
from langchain.memory import ChatMessageHistory
from langchain.chat_models import ChatOpenAI
import os
import dotenv
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")

#创建一个ChatMessageHistory对象
history=ChatMessageHistory()
history.add_ai_message("你好，我叫小智")
history.add_user_message("hi，我叫小明，请介绍一下你自己")
history.add_user_message("我是谁？")
llm=ChatOpenAI(model_name="gpt-4o-mini",temperature=0)
print(llm.invoke(history.messages))
# Out:
# C:\Users\YangYue\AppData\Local\Temp\ipykernel_10516\2155324896.py:14: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm=ChatOpenAI(model_name="gpt-4o-mini",temperature=0)
# ...
